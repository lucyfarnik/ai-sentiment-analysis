# %%
import pandas as pd

# %%
df = pd.read_csv('../../../data/youtube_data.csv')
df = df[df['Date'].isna()]
# shuffle
df = df.sample(frac=1).reset_index(drop=True)
df.head()
# Out:
# /var/folders/4c/w2fyysz50_j_234jdvb_c9wr0000gn/T/ipykernel_89220/1889035875.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../../data/youtube_data.csv')
#                            ID  \
# 0  UgwCZRF0Un24arbwZOV4AaABAg
# 1  UgwCZRF0Un24arbwZOV4AaABAg
# 2  Ugzit67kX2RkHx0VKQ14AaABAg
# 3  UgwCZRF0Un24arbwZOV4AaABAg
# 4  Ugzit67kX2RkHx0VKQ14AaABAg
#
#                                              Content User Date Location  \
# 0                                       CaseyNeistat  NaN  NaN      NaN
# 1                                       CaseyNeistat  NaN  NaN      NaN
# 2  I'd rather to never use any US made stuff thei...  NaN  NaN      NaN
# 3                                       CaseyNeistat  NaN  NaN      NaN
# 4  I'd rather to never use any US made stuff thei...  NaN  NaN      NaN
#
#    Reactions N_Children Post Title Platfrom meta lang
# 0        NaN        NaN        NaN      NaN  NaN   en
# ...
