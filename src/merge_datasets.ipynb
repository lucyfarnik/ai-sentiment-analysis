# %%
import pandas as pd

# Read in the data
yt_df = pd.read_csv('../data/yt_w_langs_en.csv')
yt_df.head()
# Out:
# /var/folders/4c/w2fyysz50_j_234jdvb_c9wr0000gn/T/ipykernel_1486/2123649053.py:4: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   yt_df = pd.read_csv('../data/yt_w_langs_en.csv')
#                            id  \
# 0  Ugx4UuB8c0ewgGUueC14AaABAg
# 1  UgzZhETXTVr5Uu-NqCp4AaABAg
# 2  UgxKHma2lTUBof2Owbt4AaABAg
# 3  UgxdpdQ7YGj1CUkNSOl4AaABAg
# 4  UgztIUfPfvCNGm8vyY94AaABAg
#
#                                                 text           username  \
# 0  We just need Korean GPT to write scripts for y...             Lanzer
# 1                            Ah yes, the end is here     Ache of Rectum
# 2         Ummm is that not how the singularity hits?  Jeremiah Deguzman
# 3  Well in Only Fans some are using their cuLitho...       Chemy Torres
# 4      😂 cuLitho in Spanish sounds like little-ass 😂         dljimenezv
#
#                    date country  likes n_children  \
# 0  2023-03-28T08:28:43Z     NaN    4.0        1.0
# ...

# %%
reddit_df = pd.read_csv('../reddit_data.csv')
reddit_df.head()
# Out:
#                  User              Date  \
# 0       FuturologyBot  05/02/2023 16:25
# 1            nblack88  05/02/2023 16:23
# 2            ISP_SERF  05/02/2023 17:18
# 3             rallar8  05/02/2023 16:35
# 4  Duckboy_Flaccidpus  05/02/2023 16:47
#
#                                              Content  Reactions       ID  \
# 0  The following submission statement was provide...          1  j7bn1af
# 1  Part of Sam's job is to be a salesman for his ...      10619  j7bmq60
# 2  As his company gets a new round of investments...        862  j7buu2l
# 3  He is marketing it as “break capitalism” becau...      10900  j7bohk2
# 4  That's what I would say if I wanted win capita...        722  j7bq8hz
#
#    N_Children                                         Post Title   Subreddit  \
# 0           0  OpenAI CEO Says His Tech Is Poised to "Break C...  Futurology
# 1          96  OpenAI CEO Says His Tech Is Poised to "Break C...  Futurology
# ...

# %%
twitter_df = pd.read_csv('../tweets.csv')
twitter_df.head()
# Out:
#    Unnamed: 0                       Date           User  \
# 0           0  2020-01-30 19:59:08+00:00  KayColesJames
# 1           1  2020-01-30 18:25:25+00:00      euscreams
# 2           2  2020-01-30 18:15:04+00:00      euscreams
# 3           3  2020-01-30 18:04:56+00:00      euscreams
# 4           4  2020-01-30 17:55:31+00:00      euscreams
#
#                                              Content           Location
# 0  .@Heritage is also honored to be ranked one of...       Richmond, VA
# 1  Civil society and the private sector can be sh...  Brussels, Belgium
# 2  Who do you report to if you're developing Arti...  Brussels, Belgium
# 3  When it comes to Artificial Intelligence and t...  Brussels, Belgium
# 4  Artificial Intelligence has great potential fo...  Brussels, Belgium
