# %%
import pandas as pd

# %%
df = pd.read_csv('../../../data/yt_w_langs.csv')
df = df[df['lang'] == 'en']
df = df[df['text'].notna()]
df
# Out:
# /var/folders/4c/w2fyysz50_j_234jdvb_c9wr0000gn/T/ipykernel_96942/3833569556.py:1: DtypeWarning: Columns (4,6,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../../data/yt_w_langs.csv')
#                                 id  \
# 14      Ugx4UuB8c0ewgGUueC14AaABAg
# 18      UgzZhETXTVr5Uu-NqCp4AaABAg
# 19      UgxKHma2lTUBof2Owbt4AaABAg
# 20      UgxdpdQ7YGj1CUkNSOl4AaABAg
# 22      UgztIUfPfvCNGm8vyY94AaABAg
# ...                            ...
# 362730  Ugzit67kX2RkHx0VKQ14AaABAg
# 362731  Ugzit67kX2RkHx0VKQ14AaABAg
# 362732  Ugzit67kX2RkHx0VKQ14AaABAg
# 362733  Ugzit67kX2RkHx0VKQ14AaABAg
# 362734  Ugzit67kX2RkHx0VKQ14AaABAg
#
#                                                      text           username  \
# 14      We just need Korean GPT to write scripts for y...             Lanzer
# 18                                Ah yes, the end is here     Ache of Rectum
# ...

# %%
df['country'].value_counts()
# Out:
# US    2475
# GB     551
# CA     376
# IN     344
# AU     227
#       ...
# DO       1
# 1        1
# ME       1
# 0        1
# OM       1
# Name: country, Length: 131, dtype: int64

# %%
# plot how many comments come from each country
df['country'].value_counts().plot(kind='bar')
# Out:
# <Axes: >
