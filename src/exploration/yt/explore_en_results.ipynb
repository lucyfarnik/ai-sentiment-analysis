# %%
import pandas as pd

# %%
df = pd.read_csv('../../../data/yt_w_langs.csv')
# Out:
# /var/folders/4c/w2fyysz50_j_234jdvb_c9wr0000gn/T/ipykernel_45167/2015432782.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../../data/yt_w_langs.csv')

# %%
df['country'].value_counts()
# Out:
# FR    6663
# VN    3958
# US    2301
# BR     817
# CA     794
#       ...
# AW       1
# JE       1
# PN       1
# SZ       1
# GD       1
# Name: country, Length: 156, dtype: int64

# %%
# plot how many comments come from each country
df['country'].value_counts().plot(kind='bar')
# Out:
# <Axes: >
